# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="google_genai:gemini-3.1-flash-lite")

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content=[{'type': 'text', 'text': 'The Moon does not have a capital city, a government, or any permanent human settlements. Under the **Outer Space Treaty of 1967**, no nation can claim sovereignty over the Moon or any other celestial body, meaning there are no countries or political borders on the lunar surface.\n\nWhile there are many "named" sites on the Moon—such as the **Sea of Tranquility** (where Apollo 11 landed) or the **South Pole-Aitken basin**—these are geographical or geological features rather than administrative centers.', 'extras': {'signature': 'EnEKbwFpFH0TpPEfIEhrPrxh/xl2hd4TBdtlpeaboqkANUaf602lHnCWH7zcAxxIy+UYyvWyZips6cRPwyViAyrELrCtTVTC7ZlKhuZZtEIo/5svSfqgPcKPY+7HRnRzZ7lvRrmpJLXHwKVkLOm7mqGSHA=='}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a0b538-1346-7010-a7e0-89d5814314ba-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10, 'output_tokens': 111, 'total_tokens': 121, 'input_token_details': {'cache_read': 0}})

# %%
print(response.content)
# Out:
# [{'type': 'text', 'text': 'The Moon does not have a capital city, a government, or any permanent human settlements. Under the **Outer Space Treaty of 1967**, no nation can claim sovereignty over the Moon or any other celestial body, meaning there are no countries or political borders on the lunar surface.\n\nWhile there are many "named" sites on the Moon—such as the **Sea of Tranquility** (where Apollo 11 landed) or the **South Pole-Aitken basin**—these are geographical or geological features rather than administrative centers.', 'extras': {'signature': 'EnEKbwFpFH0TpPEfIEhrPrxh/xl2hd4TBdtlpeaboqkANUaf602lHnCWH7zcAxxIy+UYyvWyZips6cRPwyViAyrELrCtTVTC7ZlKhuZZtEIo/5svSfqgPcKPY+7HRnRzZ7lvRrmpJLXHwKVkLOm7mqGSHA=='}}]

# %%
from pprint import pprint

pprint(response.response_metadata)

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="google_genai:gemini-3.1-flash-lite",
    # Kwargs passed to the model:
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="google_genai:gemini-3.1-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-3.1-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# [{'type': 'text', 'text': 'The Moon does not have a capital because it has no government, no countries, and no permanent human settlements. Under the **Outer Space Treaty of 1967**, which has been signed by all major spacefaring nations, no country can claim sovereignty over the Moon or any other celestial body.\n\nHowever, in science fiction, various lunar capitals are often depicted. For example, in Robert A. Heinlein’s *The Moon Is a Harsh Mistress*, the main settlement is called **Luna City**.', 'extras': {'signature': 'EnEKbwFpFH0TMfGPTYyJ4VP4QAwhvv/9Afoc4XhIGzx82Ob1GuhEVpLgemfMfZD2Hkt8g5NjlTlLdmVZtqIndivFJs9E1nOFjFi8NHxp7ptXzQdS/wJS0D28QqTVX8Aga8blpfHgbmGxiL8GOyKAa2myhw=='}}]

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
agent = create_agent(model="google_genai:gemini-3.1-flash-lite")

# %%
agent = create_agent("google_genai:gemini-3.1-flash-lite")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='96142867-a7a4-4117-874e-1a25a7f77a8f'),
#               AIMessage(content=[{'type': 'text', 'text': 'The Moon does not have a capital because it has no government, no countries, and no permanent human population. Under international law, specifically the **Outer Space Treaty of 1967**, no nation can claim sovereignty over the Moon or any other celestial body.\n\nWhile there are various lunar bases and research outposts planned by organizations like NASA (the Artemis program) and agencies from other countries, these are scientific research stations rather than political capitals.', 'extras': {'signature': 'EnEKbwFpFH0TeDycgsFABBFHxKqcZ35OrXMJol50ber5stpuMgf0LGr5bCsluGrkQ+fDuQ+8CJ1qIi8ypQmNRnqHW05cx1Wo8ySSYXK9mwbLR6ZYcJFtgFeLwU614IKpaJlCzQn9vOQu3E4NZzWu5933Xg=='}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a0b53b-ab7e-7ae2-aa37-2d58620a810e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10, 'output_tokens': 90, 'total_tokens': 100, 'input_token_details': {'cache_read': 0}})]}

# %%
print(response['messages'][-1].content)
# Out:
# [{'type': 'text', 'text': 'The Moon does not have a capital because it has no government, no countries, and no permanent human population. Under international law, specifically the **Outer Space Treaty of 1967**, no nation can claim sovereignty over the Moon or any other celestial body.\n\nWhile there are various lunar bases and research outposts planned by organizations like NASA (the Artemis program) and agencies from other countries, these are scientific research stations rather than political capitals.', 'extras': {'signature': 'EnEKbwFpFH0TeDycgsFABBFHxKqcZ35OrXMJol50ber5stpuMgf0LGr5bCsluGrkQ+fDuQ+8CJ1qIi8ypQmNRnqHW05cx1Wo8ySSYXK9mwbLR6ZYcJFtgFeLwU614IKpaJlCzQn9vOQu3E4NZzWu5933Xg=='}}]

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='3552bf21-ce36-44fb-8cce-bbce37754c7c'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='2e5ec33e-7422-475c-833e-a2f59709555e', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='51221f0f-c8be-45f5-8b49-472827ac075b'),
#               AIMessage(content=[{'type': 'text', 'text': 'It is important to clarify that **Luna City is a fictional location.** In reality, the Moon has no government, no borders, and no capital city.\n\nHowever, "Luna City" is a staple of science fiction and has been used by various authors to describe what a human settlement on the Moon might look like. Here is the lore behind the most famous versions of the city:\n\n### 1. The Classic: Robert A. Heinlein’s *The Moon Is a Harsh Mistress*\nThis is perhaps the most famous depiction of a "Luna City." In Heinlein’s 1966 novel, the capital is **Luna City** (often referred to as "Lunar City" or simply "Luna").\n*   **The Setting:** It is a subterranean city built into the walls of an extinct lava tube.\n*   **The Environment:** Because it is underground, it is protected from cosmic radiation and meteorites. It features pressurized domes and tunnels.\n*   **The Culture:** The city is portrayed as a rugged, libertarian penal colony that eventually revolts against Earth. It has its own unique subculture, slang (often using Russian-influenced syntax), and social structures based on the harsh realities of living in low gravity.\n\n### 2. Isaac Asimov’s *The Caves of Steel*\nIn the *Robot* series, Asimov describes **Under-city**, which serves as a major lunar hub. These cities are characterized by:\n*   **Domed Habitats:** Vast, pressurized environments where humans live entirely sheltered from the lunar vacuum.\n*   **Technological Integration:** The cities are heavily reliant on robotics and complex life-support systems, reflecting the themes of Asimov’s work regarding the tension between humans and machines.\n\n### 3. Pop Culture Representations\nBeyond literature, the concept of a lunar capital appears in various films and games:\n*   **Apollo 18 (and other horror/sci-fi films):** Often depicts abandoned, secret lunar bases that serve as a "capital" of shadow operations.\n*   **Video Games (like *Destiny* or *Wolfenstein*):** Often feature futuristic, militarized lunar outposts that function as hubs for the factions involved in the games.\n\n### The Reality: Why there isn\'t one yet\nWhile we don\'t have a Luna City, there are real-world plans to establish a permanent human presence:\n*   **The Artemis Program:** NASA’s current initiative aims to establish a sustainable base camp near the lunar south pole.\n*   **Lunar Gateway:** This is a planned small space station that will orbit the Moon, acting as a communication hub, science laboratory, and short-term habitation module for government agencies and commercial partners.\n*   **International Lunar Research Base (ILRB):** An initiative proposed by China and Russia to establish a base on the surface.\n\n**If we ever do build a "capital" on the Moon, it will likely look very different from the fiction:** it would likely be a sprawling complex of modular habitats, solar farms, and mining facilities designed to extract water ice from the lunar poles, rather than a single urban center. \n\n**If you were to design a capital city for the Moon, what would you name it and what would be the most important feature to include?**', 'extras': {'signature': 'EnEKbwFpFH0T/KRCOBhq8IA6fOpxCWiS9P98QRbjheXy3X/yCKINCXeilEIu9UJZB5IyCVIWf9qU5ruuPO/4qAEgksSbo8sCOyvejth9vJjhvXSuCWlzyLQSfKHCFXJWAaEbjuCNyEWATAb1Zf9+p9pLUg=='}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a0b53d-7efa-7eb1-8995-5fcb53f58ae3-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 29, 'output_tokens': 688, 'total_tokens': 717, 'input_token_details': {'cache_read': 0}})]}

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# [{'type': 'text', 'text': 'To understand **Luna City**, it is important to first distinguish between the *', 'index': 0}][{'type': 'text', 'text': 'real* lunar plans of today and the *iconic* Luna City found in science fiction.\n\nIn reality, there', 'index': 0}][{'type': 'text', 'text': ' is no "capital" of the Moon yet. However, in the world of classic science fiction—most notably in the works', 'index': 0}][{'type': 'text', 'text': ' of **Robert A. Heinlein**—Luna City is the definitive vision of lunar civilization.\n\nHere is the breakdown', 'index': 0}][{'type': 'text', 'text': ' of the legendary Luna City.\n\n---\n\n### 1. The Literary Origin: *The Moon Is a Harsh Mistress*\n', 'index': 0}][{'type': 'text', 'text': 'The most famous version of Luna City comes from Robert A. Heinlein’s 1966 Hugo Award-winning', 'index': 0}][{'type': 'text', 'text': ' novel, *The Moon Is a Harsh Mistress*.\n\n*   **The Setting:** Luna City is the primary human', 'index': 0}][{'type': 'text', 'text': ' settlement on the Moon, serving as the administrative and economic hub of the lunar penal colony. \n*   **The Environment:** It is', 'index': 0}][{'type': 'text', 'text': ' built entirely underground to protect inhabitants from solar radiation and micrometeorites. It is a labyrinth of tunnels, pressurized chambers, and "drop', 'index': 0}][{'type': 'text', 'text': ' shafts."\n*   **The Society:** Because it began as a prison colony (in the book’s lore), the society', 'index': 0}][{'type': 'text', 'text': ' is libertarian, fiercely independent, and pragmatic. They live by the acronym **TANSTAAFL** ("There Ain’t No Such Thing As', 'index': 0}][{'type': 'text', 'text': ' A Free Lunch"), reflecting their survivalist economic philosophy.\n*   **The Vibe:** It is described as a crowded', 'index': 0}][{'type': 'text', 'text': ', humid, chaotic, and industrious place. The citizens, known as "Loonies," are taller and thinner than Earth', 'index': 0}][{'type': 'text', 'text': '-born humans due to the Moon’s lower gravity.\n\n### 2. The Practical Reality (What would a', 'index': 0}][{'type': 'text', 'text': ' capital look like?)\nIf we were to build a modern "Luna City" today, it would look very different from Hein', 'index': 0}][{'type': 'text', 'text': 'lein’s version. NASA’s **Artemis program** and private companies like SpaceX and Blue Origin are currently laying', 'index': 0}][{'type': 'text', 'text': ' the groundwork for this reality.\n\n*   **Location:** Most experts agree that the capital would be located near the **Lunar', 'index': 0}][{'type': 'text', 'text': ' South Pole** (specifically the Shackleton Crater). This area receives near-constant sunlight (for solar power) and contains', 'index': 0}][{'type': 'text', 'text': ' ice in permanently shadowed regions (for water, oxygen, and rocket fuel).\n*   **Architecture:** We would use', 'index': 0}][{'type': 'text', 'text': ' **Lunar Regolith** (moon dirt). Using 3D-printing robots, we would "print" thick, radiation', 'index': 0}][{'type': 'text', 'text': '-shielding shells over inflatable habitats or lava tubes to protect residents.\n*   **The Economy:** A real Luna City wouldn', 'index': 0}][{'type': 'text', 'text': '\'t be a penal colony; it would be a **logistics hub**. It would likely serve as a "gas', 'index': 0}][{'type': 'text', 'text': ' station" for deep-space travel, a base for astronomical observatories, and a center for mining rare earth elements.', 'index': 0}][{'type': 'text', 'text': '\n\n### 3. Key Concepts of a "Luna Capital"\nIf a permanent city were to be established on the', 'index': 0}][{'type': 'text', 'text': ' Moon, it would need to master four critical technologies:\n\n1.  **In-Situ Resource Utilization (ISRU):** You', 'index': 0}][{'type': 'text', 'text': ' cannot bring everything from Earth. A capital city must mine its own water, grow its own food in greenhouses, and manufacture', 'index': 0}][{'type': 'text', 'text': ' its own construction materials from lunar dust.\n ...
